# %% [markdown]
# ### Part 1 - Time Series across 3 regions

# %%
import pandas as pd
import numpy as np
np.set_printoptions(threshold=np.inf)
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel (r'ged201.xlsx')

# %%
df = data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225385 entries, 0 to 225384
# Data columns (total 49 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 225385 non-null  int64
#  1   relid              225385 non-null  object
#  2   year               225385 non-null  int64
#  3   active_year        225385 non-null  int64
#  4   code_status        225385 non-null  object
#  5   type_of_violence   225385 non-null  int64
#  6   conflict_dset_id   225385 non-null  int64
#  7   conflict_new_id    225385 non-null  int64
#  8   conflict_name      225385 non-null  object
#  9   dyad_dset_id       225385 non-null  int64
#  10  dyad_new_id        225385 non-null  int64
#  11  dyad_name          225385 non-null  object
#  12  side_a_dset_id     225385 non-null  int64
#  13  side_a_new_id      225385 non-null  int64
#  14  side_a             225385 non-null  object
# ...

# %%
df.head()
# Out:
#        id               relid  year  active_year code_status  \
# 0  244657  IRQ-2017-1-524-322  2017            1       Clear
# 1  132140    AFG-1989-1-411-2  1989            1       Clear
# 2  130364   AFG-1989-1-411-37  1989            1       Clear
# 3  130359    AFG-1989-1-411-4  1989            1       Clear
# 4  133883   AFG-1989-1-411-39  1989            1       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id  \
# 0                 1               259              259
# 1                 1               333              333
# 2                 1               333              333
# 3                 1               333              333
# 4                 1               333              333
#
#              conflict_name  dyad_dset_id  ...   date_end deaths_a  deaths_b  \
# 0         Iraq: Government           524  ... 2017-07-31        0         4
# 1  Afghanistan: Government           724  ... 1989-01-13        6         0
# ...

# %%
#### Monthly total number of Events
df1['Month'].value_counts()
# Out:
# 5     20325
# 7     20130
# 1     19904
# 4     19797
# 6     19631
# 8     19291
# 10    19027
# 9     18644
# 3     18390
# 11    17218
# 2     16796
# 12    16232
# Name: Month, dtype: int64

# %%
df1 = df.set_index('date_start')

# %%
df1['Year'] = df1.index.year
df1['Month'] = df1.index.month

# %%
sns.set(rc={'figure.figsize':(10, 8)})
g =sns.barplot(x="Month", y="best",
              data=df1)
plt.ylabel('Best - Total no. of deaths across all 3 regions')
plt.xlabel('Months')
plt.show()

# %%
df_Kabul = df1[(df1.adm_2 == 'Kabul district')]
df_Kunduz = df1[(df1.adm_2 == 'Kunduz district')]
df_Ghazni = df1[(df1.adm_2 == 'Ghazni district')]

# %%
sns.set(rc={'figure.figsize':(10, 8)})
g =sns.barplot(x="Month", y="best",
              data=df_Kabul)
plt.ylabel('Best - Total no. of deaths')
plt.xlabel('Kabul')
plt.show()

# %%
sns.set(rc={'figure.figsize':(10, 8)})
g =sns.barplot(x="Month", y="best",
              data=df_Kunduz)
plt.ylabel('Best - Total no. of deaths')
plt.xlabel('Kunduz')
plt.show()

# %%
sns.set(rc={'figure.figsize':(10, 8)})
g =sns.barplot(x="Month", y="best",
              data=df_Ghazni)
plt.ylabel('Best - Total no. of deaths')
plt.xlabel('Ghazni')
plt.show()

# %% [markdown]
# ### In the figure below, major death rate has been observed between 1992 to 1996 for Kabul district

# %%
sns.set(rc={'figure.figsize':(20, 10)})
df_Kabul['best'].plot(linewidth=3, title = 'Total no. of deaths in Kabul from 1989 to 2019 ', color='green')
plt.ylabel('Best - Total no. of deaths across each event')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# ### In the figure below for Kunduz it can be seen that there have been significant amounts of deaths between 2010 and 2020

# %%
sns.set(rc={'figure.figsize':(20, 10)})
df_Kunduz['best'].plot(linewidth=3, title = 'Total no. of deaths in Kunduz from 1989 to 2019 ', color='purple')
plt.ylabel('Best - Total no. of deaths across each event')
plt.xlabel('Time')
plt.show()

# %%
sns.set(rc={'figure.figsize':(20, 10)})
df_Ghazni['best'].plot(linewidth=3, title = 'Total no. of deaths in Ghazni from 1989 to 2019 ', color='blue')
plt.ylabel('Best - Total no. of deaths across each event')
plt.xlabel('Time')
plt.show()
